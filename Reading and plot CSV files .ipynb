# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Sales Report.csv")

# %%
x1= []
y1= []
Region = data["Region"]
Sold = data["Units Sold"]
x1= list(Region)
y1= list(Sold)
print(x1)
print(y1)
# Out:
# ['Australia and Oceania', 'Central America and the Caribbean', 'Europe', 'Sub-Saharan Africa', 'Sub-Saharan Africa', 'Australia and Oceania', 'Sub-Saharan Africa', 'Sub-Saharan Africa', 'Sub-Saharan Africa', 'Sub-Saharan Africa', 'Asia', 'Sub-Saharan Africa', 'Asia', 'Central America and the Caribbean', 'Asia', 'Europe', 'Asia', 'Sub-Saharan Africa', 'Asia', 'Australia and Oceania', 'Europe', 'Europe', 'Central America and the Caribbean', 'Australia and Oceania', 'Europe', 'Europe', 'Australia and Oceania', 'Sub-Saharan Africa', 'Europe', 'Sub-Saharan Africa', 'Europe', 'Sub-Saharan Africa', 'Australia and Oceania', 'Asia', 'Sub-Saharan Africa', 'Central America and the Caribbean', 'Middle East and North Africa', 'Sub-Saharan Africa', 'Asia', 'Europe', 'Sub-Saharan Africa', 'Middle East and North Africa', 'Sub-Saharan Africa', 'Europe', 'Asia', 'Sub-Saharan Africa', 'Europe', 'Europe', 'Europe', 'Sub-Saharan Africa', 'Europe', 'Sub-Saharan Africa', 'Middle East and North Africa', 'Su
# ...

# %%
plt.figure(figsize = (20,20))
plt.scatter(x1,y1,c="r")
plt.xlabel("Regions")
plt.ylabel("Units Sold")
plt.title("Item type vs Units sold")
plt.show()

# %%
plt.figure(figsize=(20,7))
plt.bar(x1,y1)
plt.xlabel("Region")
plt.ylabel("Units Sold")
plt.title("Region wise Sales")
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.hist(y1,bins = 25,color = 'b') 
plt.xlabel('Units Sold')
plt.ylabel('No of Values')
plt.title("Sales") 
plt.show()

# %%
#x1= []
#y1= []
#Region = data["Region"]
#Sold = data["Units Sold"]
#x1= list(Region)
#y1= list(Sold)
#print(x1)
#print(y1)
plt.pie(y1, labels=x1,colors=colors,shadow=True,autopct='%0.3f%%')
plt.title('Sales Data')
plt.show()

# %%
x2= []
y2= []
Revenue = data["Units Sold"]
Sold = data["Total Revenue"]
x2= list(Revenue)
y2= list(Sold)
plt.plot(x2,y2,"r")
plt.xlabel("Revenue")
plt.ylabel("Sold")
plt.title("Sales")
plt.show()

# %%
data2 = pd.read_csv("Exams list.csv")
data2
# Out:
#         Student name Exam name   Exam date  Exam points
# 0       James Walker   Biology  05/06/2016           31
# 1      Velma Clemons   Biology  05/06/2016           43
# 2     Kibo Underwood   Biology  05/06/2016           81
# 3        Louis Mcgee   Biology  05/06/2016           11
# 4       Phyllis Paul   Biology  05/06/2016           18
# 5     Zenaida Decker   Biology  05/06/2016           55
# 6    Gillian Tillman   Biology  05/06/2016           38
# 7    Constance Boone   Biology  05/06/2016           16
# 8  Giselle Lancaster   Biology  05/06/2016           73
# 9   Kirsten Mcdowell   Biology  05/06/2016           16

# %%
#pie chart
a2 = []
b2 = []
plt.figure(figsize = (6,6))
Marks = data2["Exam points"]
Name = data2["Student name"]
a2 = list(Marks)
b2 = list(Name)
explode = (0,0,0,0.5,0.2,0,0,0.3,0,0.3)
plt.pie(a2, labels = b2,explode = explode,shadow = True, autopct = "%0.2f%%")
plt.title("Student Marks")
plt.show()

# %%
#Histogram
plt.hist(a2,bins = 7,color = "r")
plt.xlabel("Marks scored")
plt.ylabel("no of students")
plt.title("Biology Scorecard")
plt.show()

# %%
#scatter plots
plt.figure(figsize = (15,5))
plt.scatter(b2,a2,c="g")
plt.xlabel("Student name")
plt.ylabel("Marks Scored")
plt.title("Biology Scorecard")
plt.show()
